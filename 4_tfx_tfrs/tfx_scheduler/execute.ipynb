# %%
import papermill as pm
import os
pm.execute_notebook(
   './final.ipynb',
   './test.ipynb'
)
# Out:
# Executing:   0%|          | 0/60 [00:00<?, ?cell/s]
# 2023-02-24 05:55:46.847850: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-24 05:55:47.036260: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-24 05:55:47.036323: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
import os

dir_path = "./serving_model/testt"

subdirs = [os.path.join(dir_path, d) for d in os.listdir(dir_path) if os.path.isdir(os.path.join(dir_path, d))]

# %%
import zipfile
import os

def zipdir(path, ziph):
    for root, dirs, files in os.walk(path):
        for file in files:
            ziph.write(os.path.join(root, file))

zip_name = "test.zip"
dir_path = subdirs[-1]

zipf = zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED)
zipdir(dir_path, zipf)
zipf.close()

# %%
import boto3
from botocore.client import Config
#ENV
ACCESS_KEY_ID = '' #s3 관련 권한을 가진 IAM계정 정보
ACCESS_SECRET_KEY = ''
BUCKET_NAME = ''


s3 = boto3.resource(
    's3',
    aws_access_key_id=ACCESS_KEY_ID,
    aws_secret_access_key=ACCESS_SECRET_KEY,
    config=Config(signature_version='s3v4')
)

s3.meta.client.upload_file('./test.zip', 'baehanjin', 'model.zip')
